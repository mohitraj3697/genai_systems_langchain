# %% [markdown]
# Built-in Tool - DuckDuckGo Search

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('top 10 programming languages in 2024')

print(results)
# Out:
# 11 Nov 2025—Top 20 Programming Languages to Learn · 1. Python · 2. JavaScript · 3. Java · 4. C# · 5. C++ · 6. PHP · 7. Ruby · 8. Swift. 23 Sept 2025—In the “Spectrum” default ranking, which is weighted with the interests of IEEE members in mind, we see that once again Python has the top spot, with the ... 4 days ago—Python, JavaScript, and Java are currently the most demanded programming languages, with 45.7% of recruiters looking to hire Python developers, 41.5% searching ... 18 Apr 2025—Python, JavaScript, and Java continue to dominate, but emerging languages like Kotlin, Go, and Rust are gaining traction due to their modern programming ... 19 Nov 2025—Most used programming languages among developers worldwide as of 2025 ; TypeScript, 43.6% ; Java, 29.4% ; C#, 27.8% ; C++, 23.5%.

# %%
print(search_tool.name)
print(search_tool.description)
print(search_tool.args)
# Out:
# duckduckgo_search
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# Built-in Tool - Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results = shell_tool.invoke('echo Hello, World!')

print(results)
# Out:
# Executing command:
#  echo Hello, World!
# Hello, World!
